# %%
import random
import re
from urllib.request import urlopen
import datetime
from bs4 import BeautifulSoup


random.seed(datetime.datetime.now())

def getLinks(articleUrl) :
    html = urlopen("https://en.wikipedia.org" + articleUrl)
    soup = BeautifulSoup(html, "html.parser")
    return soup.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))

links = getLinks("/wiki/Kevin_Bacon")


while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Michael_Caine
# /wiki/Matt_Damon
# /wiki/Sydney_Box
# /wiki/Woody_Allen
# /wiki/Kenneth_Branagh
# /wiki/Hal_Holbrook
# /wiki/IMDb
# /wiki/First_Amendment_to_the_United_States_Constitution
# /wiki/United_States_Reports
# /wiki/Alexander_J._Dallas_(statesman)
# /wiki/Elm_Bluff,_Alabama
# /wiki/International_Standard_Book_Number
# /wiki/OCLC
# /wiki/Library_Journal
# /wiki/Belgrade,_Montana
# /wiki/Sidney,_Montana
# /wiki/Saskatchewan
# /wiki/Coat_of_arms_of_Saskatchewan
# /wiki/Coat_of_arms_of_Victoria,_British_Columbia
# /wiki/Miramichi_Herald
# /wiki/Coat_of_arms_of_Manitoba
# /wiki/Coat_of_arms_of_Ontario
# /wiki/De_facto
# /wiki/New_Zealand
# /wiki/Education_in_New_Zealand
# /wiki/Supreme_Court_of_New_Zealand
# /wiki/New_Zealand_Court_of_Appeal
# /wiki/Wellington
# /wiki/Te_Kuiti
# /wiki/Rugby_Union
# /wiki/Llargues
# /wiki/Galotxa
# /wiki/Montserrat,_Valencia
# /wiki/Guadassuar
# /wiki/Alcublas
# /wiki/Losa_del_Obispo
# /wiki/Beniparrell
# /wiki/Benissoda
# /wiki/Venta_del_Moro
# /wiki/Alcublas
# /wiki/Sollana
# /wiki/Montroy,_Valencia
# /wiki/Llanera_de_Ranes
# /wiki/La_Pobla_de_Vallbona
# /wiki/Benicolet
# /wiki/Tavernes_Blanques
# /wiki/Requena,_Valencia
# /wiki/Benaguasil
# /wiki/Alcublas
# /wiki/La_Pobla_Llarga
# /wiki/Guardamar_de_la_Safor
# /wiki/Daim%C3%BAs
# /wiki/Camporrobles
# /wiki/Benisan%C3%B3
# /wiki/Torres_Torres
# /wiki/Benig%C3%A0nim
# /wiki/Alberic,_Valencia
# /wiki/Tous,_Valencia
# /wiki/Ribera_Alta_(comarca)
# /wiki/Alt_Maestrat
# /wiki/Benassal
# /wiki/Alboc%C3%A0sser
# /wiki/Castell%C3%B3n_de_la_Plana
# /wiki/Vallat
# /wiki/Tales,_Castell%C3%B3n
# /wiki/Moncofa
# /wiki/Valencian_Community
# /wiki/Elche
# /wiki/France
# /wiki/Tunisia
# /wiki/Macedonia_naming_dispute
# /wiki/Media_of_North_Macedonia
# /wiki/2012_Republic_of_Macedonia_inter-ethnic_violence
# /wiki/List_of_power_stations_in_North_Macedonia
# /wiki/List_of_power_stations_in_Serbia
# /wiki/List_of_power_stations_in_Uganda
# /wiki/List_of_power_stations_in_Tajikistan
# /wiki/List_of_power_stations_in_the_Democratic_Republic_of_the_Congo
# /wiki/Run_of_river
# /wiki/Turgo_turbine
# /wiki/Water_turbine
# /wiki/Pitting_corrosion
# /wiki/Thiosulfate
# /wiki/Disproportionation
# /wiki/International_Standard_Book_Number
# /wiki/ISO/IEC_9797-1
# /wiki/ISO_216
# /wiki/ISO_9564
# /wiki/ISO/IEC_8859-3
# /wiki/%C4%A0
# /wiki/%C4%A2
# /wiki/IJ_(digraph)
# /wiki/List_of_Latin-script_keyboard_layouts
# /wiki/Dvorak_Simplified_Keyboard
# /wiki/Vowel
# /wiki/Near-open_front_unrounded_vowel
# /wiki/X-SAMPA
# /wiki/Voiceless_uvular_trill
# /wiki/Voiceless_dental_fricative
# /wiki/Spanish_orthography
# /wiki/Student
# /wiki/Student_activism
# /wiki/Ann_Arbor
# /wiki/Lyndon_Township,_Michigan
# /wiki/Median_household_income
# /wiki/List_of_countries_by_average_wage
# /wiki/Italy
# /wiki/Commissioner_for_Human_Rights
# /wiki/Awareness_raising
# /wiki/Chicago,_Illinois
# /wiki/Oak_Brook,_Illinois
# /wiki/William_J._Cullerton
# /wiki/357th_Fighter_Squadron
# /wiki/Dauphin_Island_Air_Force_Station
# /wiki/514th_Air_Defense_Group
# /wiki/327th_Aircraft_Sustainment_Wing
# /wiki/USS_Vigil_(AGR-12)
# /wiki/SS_Newton_D._Baker
# /wiki/SS_Stephen_R._Mallory
# /wiki/Isbrandtsen_Steamship_Company
# /wiki/P%26O_Nedlloyd
# /wiki/P%26O_Ferries
# /wiki/Orient_Steam_Navigation_Company
# /wiki/P%26O_Princess_Cruises
# /wiki/Princess_Cruises
# /wiki/MV_Columbus
# /wiki/Regal_Princess_(2014)
# /wiki/HSF_Festos_Palace
# /wiki/Laksamana-class_corvette
# /wiki/Costa_Serena
# /wiki/MS_al-Salam_Boccaccio_98
# /wiki/Carnival_Liberty
# /wiki/Carnival_Victory
# /wiki/Costa_Pacifica
# /wiki/Concordia_class_cruise_ship
# /wiki/Carnival_Cruise_Line
# /wiki/Gross_tonnage
# /wiki/Intermodal_container
# /wiki/Hofstra_University
# /wiki/Ontario_Junior_Hockey_League
# /wiki/Burlington_Cougars
# /wiki/Basketball
# /wiki/Angola_Second_Division_Basketball_Championship
# /wiki/I_Liga_(basketball)
# /wiki/%C5%9Al%C4%85sk_Wroc%C5%82aw_(basketball)
# /wiki/PLK_Rookie_of_the_Year
# /wiki/Rosa_Radom
# /wiki/Polish_Basketball_Cup
# /wiki/Gdynia
# /wiki/Lithuania
# /wiki/Kruonis_Pumped_Storage_Plant
# /wiki/Kaunas_Reservoir
# /wiki/Drainage_basin
# /wiki/Road
# /wiki/Bicycle_lane
# /wiki/One-way_street
# /wiki/Malaysia
# /wiki/Papua_New_Guinea
# /wiki/Louisiade_Archipelago
# /wiki/Calvados_Chain
# /wiki/Pana_Rora_Island
# /wiki/Goaribari_Island
# /wiki/Conflict_Group
# /wiki/Nukumanu_Islands
# /wiki/Long_Island_(Papua_New_Guinea)
# /wiki/Goaribari_Island
# /wiki/Little_Ndrova_Island
# /wiki/New_Britain
# /wiki/Dampier_Strait_(Papua_New_Guinea)
# /wiki/Huon_Gulf
# /wiki/Jean-Michel_Huon_de_Kermadec
# /wiki/New_Caledonia
# /wiki/Lists_of_islands
# /wiki/List_of_islands_of_Italy
# /wiki/Pre-Nuragic_Sardinia
# /wiki/Gonnostramatza
# /wiki/Suni,_Sardinia
# /wiki/Nughedu_Santa_Vittoria
# /wiki/Sardinian_language
# /wiki/Tuscan_dialect
# /wiki/Gallo-Romance_languages
# /wiki/Spain
# /wiki/Roman_Theatre_(M%C3%A9rida)
# /wiki/Scaenae_frons
# /wiki/Turkey
# /wiki/Economy_of_Madagascar
# /wiki/Madagascar_Oil
# /wiki/Houston_Business_Journal
# /wiki/Milwaukee
# /wiki/Wisconsin_State_Senate
# /wiki/Alaska_Senate
# /wiki/Ben_Stevens
# /wiki/Washington,_D.C.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#    1391             self.sock = self._context.wrap_socket(self.sock,
# -> 1392                                                   server_hostname=server_hostname)
#    1393
#
# ~\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# ~\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#
# OSError: [WinError 10051] 연결할 수 없는 네트워크에서 소켓 작업을 시도했습니다
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-2-803f828512b9> in <module>
#      19     newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
#      20     print(newArticle)
# ---> 21     links = getLinks(newArticle)
#
# <ipython-input-2-803f828512b9> in getLinks(articleUrl)
#       9
#      10 def getLinks(articleUrl) :
# ---> 11     html = urlopen("https://en.wikipedia.org" + articleUrl)
#      12     soup = BeautifulSoup(html, "html.parser")
#      13     return soup.find("div", {"id":"bodyContent"}).findAll("a", href=re.compile("^(/wiki/)((?!:).)*$"))
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [WinError 10051] 연결할 수 없는 네트워크에서 소켓 작업을 시도했습니다>

# %%
import re
from bs4 import BeautifulSoup
from urllib.request import urlopen
import random
import datetime

random.seed(datetime.datetime.now())

def getLinks(articleUrl):
    html = urlopen("https://movie.naver.com" + articleUrl)
    soup = BeautifulSoup(html, "html.parser")
    return soup.find("div", {"id":"content"}).findAll("a", href=re.compile("^(/movie/point)((?!:).)*$"))
links = getLinks("/movie/point/af/list.nhn?st=mcode&sword=171539")

while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    print(newArticle)
    links = getLinks(newArticle)
