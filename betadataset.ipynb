# %% [markdown]
# ### 영화 데이터 추출 프로그램

# %%
import re
import csv
from bs4 import BeautifulSoup
from urllib.request import urlopen
linkList = []
mvGenre = []
comp = "/movie/sdb/browsing/bmovie.nhn?genre" # 비교용
base_url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=pnt&date=20190825&page={}"
for j in range(5): # 원하는 페이지 까지 루틴
    url = base_url.format(j+1) #랭킹 페이지 값을 변경
    page = urlopen(url)
    soup = BeautifulSoup(page, "html.parser") # beautifulsoup 링크 페이지를 실행
    #print(soup) 
    print("진행상황",j, "/40", url) # 랭킹 페이지가 변경 되는 것을 확인

    #영화 링크를 가져오는 부분, 이부분에서 문제가 있음을 알 수 있음
    linkList = []
    for link in soup.find("div", {"id":"content"}).findAll("a", href=re.compile("^(/movie/point)((?!:).)*$")):
        if 'href' in link.attrs:   
            #print('https://movie.naver.com' + link.attrs['href'])
            movieLink = 'https://movie.naver.com' + link.attrs['href']
            linkList.append(movieLink)
            #print(movieLink)
    #         page = urlopen(movieLink)
    #         soup = BeautifulSoup(page, "html.parser")
    #         print(soup)
    
    for i in range(50): #가져온 랭킹 페이지의 영화 링크대로 하나하나 추출작업
        f = open('output.csv', 'a', encoding='utf-8', newline='')
        url2 = linkList[i]
        page2 = urlopen(url2)
        soup2 = BeautifulSoup(page2, "html.parser")

        #영화 이름과 장르 추출
        mvTitle = soup2.find("div", {"class": "choice_movie_info"}).find("a").text

        for atag in soup2.find("div", {"class": "choice_movie_info"}).find("td").findAll("a"):
            if comp in str(atag):
                mvGenre.append(atag.text)

        print(mvTitle) #제목 크롤링
        print(mvGenre) #장르 크롤링

        #영화 평점 추출
        stPoint = soup2.find("div", {"class":"fl point_type_b"}).find("div")
        stPoint = str(stPoint)
        stPoint = stPoint[31:35]
        stPoint = float(stPoint)/10
        stPoint = round(stPoint, 2)
        print(stPoint)

        #영화 투표수 추출
        soup2.findAll("span")
        for i in soup2.findAll("td"):
            if i.find("em") != None:
                voteCnt = i.find("em").text
                print(voteCnt)

        # 영화 포스터 추출
        poster = soup2.find("div", {"class": "fl"}).find("img")['src']
        print(poster)
        print("")

        #csv 파일에 저장
        wr = csv.writer(f)
        wr.writerow([mvTitle, mvGenre, stPoint, voteCnt, poster])
        del mvGenre[:]
        f.close()
# Out:
# 진행상황 0 /40 https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=pnt&date=20190825&page=1
# 그린 북
# ['드라마']
# 9.61
# 5939
# https://movie-phinf.pstatic.net//20190115_228/1547528180168jgEP7_JPEG/movie_image.jpg?type=m210
#
# 가버나움
# ['드라마']
# 9.59
# 2883
# https://movie-phinf.pstatic.net//20190109_149/1546998123676c6LjJ_JPEG/movie_image.jpg?type=m210
#
# 주전장
# ['다큐멘터리']
# 9.53
# 869
# https://movie-phinf.pstatic.net//20190712_279/1562912698606Qv0GH_JPEG/movie_image.jpg?type=m210
#
# 베일리 어게인
# ['모험', '코미디', '드라마']
# 9.53
# 2147
# https://movie-phinf.pstatic.net//20181031_264/1540949415228uy0j3_JPEG/movie_image.jpg?type=m210
#
# 아일라
# ['드라마', '전쟁']
# 9.48
# 1721
# https://movie-phinf.pstatic.net//20180524_108/1527129319423XRTcI_JPEG/movie_image.jpg?type=m210
#
# 원더
# ['드라마']
# 9.46
# 2839
# https://movie-phinf.pstatic.net//20171229_112/1514526663263n37r0_JPEG/movie_image.jpg?type=m210
#
# 당갈
# ['드라마', '액션']
# 9.43
# 1980
# https://movie-phinf.pstatic.net//20180329_2/1522287706725roSen_JPEG/movie_image.jpg?type=m210
#
# 쇼생크 탈출
# ['드라마']
# 9.43
# 17678
# https://movie-phinf.pstatic.net//20160119_278/14531650465287bcuk_JPEG/movie_image.jpg?type=m210
#
# 보헤미안 랩소디
# ['드라마']
# 9.42
# 39382
# https://movie-phinf.pstatic.net//20181213_264/1544692854634ss65r_JPEG/movie_image.jpg?type=m210
#
# 터미네이터 2
# ['SF', '액션', '스릴러']
# 9.41
# 6962
# https://movie-phinf.pstatic.net//20190808_222/1565227513796UPGNm_JPEG/movie_image.jpg?type=m210
#
# 덕구
# ['드라마']
# 9.41
# 2482
# https://movie-phinf.pstatic.net//20180312_10/1520835949152TqOUm_JPEG/movie_image.jpg?type=m210
#
# 알라딘
# ['모험', '가족', '판타지', '뮤지컬', '멜로/애정/로맨스']
# 9.4
# 26101
# https://movie-phinf.pstatic.net//20190524_104/1558663170174Q2mmw_JPEG/movie_image.jpg?type=m210
#
# 월-E
# ['애니메이션', 'SF', '가족', '코미디', '멜로/애정/로맨스', '모험']
# 9.4
# 9965
# https://movie-phinf.pstatic.net//20111222_250/1324545484806T0DN9_JPEG/movie_image.jpg?type=m210
#
# 나 홀로 집에
# ['모험', '범죄', '가족', '코미디']
# 9.39
# 4067
# https://movie-phinf.pstatic.net//20111222_256/1324527530062tFbqt_JPEG/movie_image.jpg?type=m210
#
# 라이언 일병 구하기
# ['전쟁', '액션', '드라마']
# 9.39
# 4274
# https://movie-phinf.pstatic.net//20111222_4/1324498435937yqCYm_JPEG/movie_image.jpg?type=m210
#
# 인생은 아름다워
# ['드라마', '코미디']
# 9.39
# 12059
# https://movie-phinf.pstatic.net//20160321_156/14585243498978uRh9_JPEG/movie_image.jpg?type=m210
#
# 빽 투 더 퓨쳐
# ['SF', '코미디']
# 9.4
# 3043
# https://movie-phinf.pstatic.net//20150924_194/1443056454769VJKkL_JPEG/movie_image.jpg?type=m210
#
# 매트릭스
# ['SF', '액션']
# 9.39
# 4669
# https://movie-phinf.pstatic.net//20160907_158/1473230958410gjEYe_JPEG/movie_image.jpg?type=m210
#
# 사운드 오브 뮤직
# ['멜로/애정/로맨스', '뮤지컬', '드라마']
# 9.39
# 4440
# https://movie-phinf.pstatic.net//20161124_209/1479966118269WuVYF_JPEG/movie_image.jpg?type=m210
#
# 포레스트 검프
# ['드라마', '코미디']
# 9.39
# 7756
# https://movie-phinf.pstatic.net//20160901_187/1472711688297YP2jH_JPEG/movie_image.jpg?type=m210
#
# 헬프
# ['드라마']
# 9.39
# 3499
# https://movie-phinf.pstatic.net//20111223_214/1324649693153G81OH_JPEG/movie_image.jpg?type=m210
#
# 글래디에이터
# ['액션', '드라마']
# 9.38
# 4162
# https://movie-phinf.pstatic.net//20130419_151/1366338731242XqgJS_JPEG/movie_image.jpg?type=m210
#
# 어벤져스: 엔드게임
# ['액션', 'SF']
# 9.38
# 68748
# https://movie-phinf.pstatic.net//20190417_250/1555465284425i6WQE_JPEG/movie_image.jpg?type=m210
#
# 살인의 추억
# ['범죄', '미스터리', '스릴러', '코미디', '드라마']
# 9.38
# 6130
# https://movie-phinf.pstatic.net//20111222_166/1324548172003mpyIa_JPEG/movie_image.jpg?type=m210
#
# 토이 스토리 3
# ['애니메이션', '모험', '코미디', '가족', '판타지']
# 9.38
# 7611
# https://movie-phinf.pstatic.net//20111223_166/1324619308419RAp5L_JPEG/movie_image.jpg?type=m210
#
# 센과 치히로의 행방불명
# ['애니메이션', '판타지', '모험', '가족']
# 9.36
# 12954
# https://movie-phinf.pstatic.net//20150113_96/1421113909808LPjqA_JPEG/movie_image.jpg?type=m210
#
# À§´ëÇÑ ¼î¸Ç
# ['µå¶ó¸¶', '¹ÂÁöÄÃ']
# 9.38
# 13736
# https://movie-phinf.pstatic.net//20171218_47/1513561221134wvRja_JPEG/movie_image.jpg?type=m210
#
# 클래식
# ['멜로/애정/로맨스', '드라마']
# 9.36
# 8615
# https://movie-phinf.pstatic.net//20111222_233/1324486884038nu8Xk_JPEG/movie_image.jpg?type=m210
#
# 죽은 시인의 사회
# ['드라마']
# 9.36
# 7227
# https://movie-phinf.pstatic.net//20160811_237/1470893687476y2lJU_JPEG/movie_image.jpg?type=m210
#
# 아이 캔 스피크
# ['드라마']
# 9.36
# 14798
# https://movie-phinf.pstatic.net//20170908_108/1504837489518BdEBl_JPEG/movie_image.jpg?type=m210
#
# 레옹
# ['범죄', '액션', '드라마']
# 9.36
# 9427
# https://movie-phinf.pstatic.net//20180614_21/1528939162378wtwMm_JPEG/movie_image.jpg?type=m210
#
# 헌터 킬러
# ['액션', '스릴러']
# 9.36
# 3313
# https://movie-phinf.pstatic.net//20181212_219/1544577062842KarfK_JPEG/movie_image.jpg?type=m210
#
# 반지의 제왕: 왕의 귀환
# ['판타지', '모험', '액션', '전쟁']
# 9.36
# 6994
# https://movie-phinf.pstatic.net//20170112_240/1484183668820LGsTJ_JPEG/movie_image.jpg?type=m210
#
# 동주
# ['드라마']
# 9.36
# 11047
# https://movie-phinf.pstatic.net//20160205_299/1454651273096sYmsK_JPEG/movie_image.jpg?type=m210
#
# 굿바이 마이 프랜드
# ['드라마']
# 9.35
# 2604
# https://movie-phinf.pstatic.net//20111222_51/1324565484058LDGWr_JPEG/movie_image.jpg?type=m210
#
# 캐스트 어웨이
# ['드라마', '모험']
# 9.36
# 2607
# https://movie-phinf.pstatic.net//20111222_155/1324482759519Uvkyl_JPEG/movie_image.jpg?type=m210
#
# 여인의 향기
# ['드라마', '코미디']
# 9.35
# 2795
# https://movie-phinf.pstatic.net//20111222_152/1324529496355rYAnm_JPEG/movie_image.jpg?type=m210
#
# 주토피아
# ['애니메이션', '액션', '모험', '코미디', '가족']
# 9.35
# 18473
# https://movie-phinf.pstatic.net//20160217_153/1455686083975zjajH_JPEG/movie_image.jpg?type=m210
#
# 히든 피겨스
# ['드라마']
# 9.35
# 3690
# https://movie-phinf.pstatic.net//20170323_41/14902311518230x8pp_JPEG/movie_image.jpg?type=m210
#
# 세 얼간이
# ['코미디']
# 9.34
# 25825
# https://movie-phinf.pstatic.net//20161005_215/1475647328961ETC6k_JPEG/movie_image.jpg?type=m210
#
# 클레멘타인
# ['액션', '드라마']
# 9.34
# 21310
# https://movie-phinf.pstatic.net//20111222_33/1324533894503h3QAH_JPEG/movie_image.jpg?type=m210
#
# 지금, 만나러 갑니다
# ['멜로/애정/로맨스', '드라마', '판타지']
# 9.34
# 15438
# https://movie-phinf.pstatic.net//20180403_286/1522736958040KRAkQ_JPEG/movie_image.jpg?type=m210
#
# 타이타닉
# ['멜로/애정/로맨스', '드라마']
# 9.34
# 20628
# https://movie-phinf.pstatic.net//20181129_107/1543452551390CN9TW_JPEG/movie_image.jpg?type=m210
#
# 쉰들러 리스트
# ['드라마', '전쟁']
# 9.34
# 3596
# https://movie-phinf.pstatic.net//20190122_81/1548118455965SCCSW_JPEG/movie_image.jpg?type=m210
#
# 언터처블: 1%의 우정
# ['코미디', '드라마']
# 9.34
# 7641
# https://movie-phinf.pstatic.net//20120206_287/1328516303779LrC9h_JPEG/movie_image.jpg?type=m210
#
# 서유기 2 - 선리기연
# ['코미디', '액션', '모험', '판타지', '멜로/애정/로맨스']
# 9.34
# 3790
# https://movie-phinf.pstatic.net//20111223_77/1324614581048LAc6L_JPEG/movie_image.jpg?type=m210
#
# 에이리언 2
# ['SF', '공포', '스릴러', '액션']
# 9.33
# 1746
# https://movie-phinf.pstatic.net//20111223_189/1324569548247L26km_JPEG/movie_image.jpg?type=m210
#
# 모노노케 히메
# ['애니메이션', '모험', '액션']
# 9.34
# 4298
# https://movie-phinf.pstatic.net//20111222_63/1324483671210VVU36_JPEG/movie_image.jpg?type=m210
#
# 패왕별희
# ['드라마']
# 9.33
# 2018
# https://movie-phinf.pstatic.net//20170309_211/1489024538678ITB9w_JPEG/movie_image.jpg?type=m210
#
# 굿 윌 헌팅
# ['드라마']
# 9.33
# 4317
# https://movie-phinf.pstatic.net//20160810_49/14708058043034cuPp_JPEG/movie_image.jpg?type=m210
#
# 진행상황 1 /40 https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=pnt&date=20190825&page=2
# 그대를 사랑합니다
# ['드라마']
# 9.33
# 7687
# https://movie-phinf.pstatic.net//20111223_56/13246314342663riGK_JPEG/movie_image.jpg?type=m210
#
# 아마데우스
# ['드라마']
# 9.33
# 2983
# https://movie-phinf.pstatic.net//20150915_185/1442285641128msR7J_JPEG/movie_image.jpg?type=m210
#
# 집으로...
# ['드라마', '가족']
# 9.33
# 2515
# https://movie-phinf.pstatic.net//20190805_26/1564994340344jQru8_JPEG/movie_image.jpg?type=m210
#
# 반지의 제왕: 두 개의 탑
# ['판타지', '모험', '액션']
# 9.32
# 2700
# https://movie-phinf.pstatic.net//20170112_295/1484183596684X2ucM_JPEG/movie_image.jpg?type=m210
#
# 다시 태어나도 우리
# ['다큐멘터리']
# 9.33
# 1006
# https://movie-phinf.pstatic.net//20170831_207/1504142664133FKxXK_JPEG/movie_image.jpg?type=m210
#
# 드래곤 길들이기
# ['애니메이션', '모험', '코미디', '가족', '판타지']
# 9.33
# 8764
# https://movie-phinf.pstatic.net//20190102_130/1546395842249fT9Ei_JPEG/movie_image.jpg?type=m210
#
# 다크 나이트
# ['액션', '범죄', '드라마', '미스터리']
# 9.33
# 26402
# https://movie-phinf.pstatic.net//20170608_209/1496886337035SDPLy_JPEG/movie_image.jpg?type=m210
#
# 울지마 톤즈
# ['다큐멘터리']
# 9.33
# 4611
# https://movie-phinf.pstatic.net//20111223_289/1324622149942dtKyL_JPEG/movie_image.jpg?type=m210
#
# 알라딘
# ['애니메이션', '뮤지컬', '코미디', '가족', '모험', '드라마', '멜로/애정/로맨스']
# 9.34
# 579
# https://movie-phinf.pstatic.net//20170418_64/1492495808221lgtrR_JPEG/movie_image.jpg?type=m210
#
# 폴란드로 간 아이들
# ['다큐멘터리', '드라마']
# 9.32
# 533
# https://movie-phinf.pstatic.net//20181004_63/1538615669479nezAh_JPEG/movie_image.jpg?type=m210
#
# 트루먼 쇼
# ['코미디', '드라마', 'SF']
# 9.33
# 6460
# https://movie-phinf.pstatic.net//20181030_24/1540878641446PBOcp_JPEG/movie_image.jpg?type=m210
# 미세스 다웃파이어
# ['코미디', '가족', '드라마']
# 9.34
# 807
# https://movie-phinf.pstatic.net//20111222_82/1324538552665F1zbw_JPEG/movie_image.jpg?type=m210
#
# 더 록
# ['액션']
# 9.32
# 2535
# https://movie-phinf.pstatic.net//20111221_286/1324471145026nKaBX_JPEG/movie_image.jpg?type=m210
#
# 라푼젤
# ['애니메이션', '코미디', '가족', '판타지', '뮤지컬', '멜로/애정/로맨스']
# 9.33
# 6816
# https://movie-phinf.pstatic.net//20170418_162/1492497182954jDK7m_JPEG/movie_image.jpg?type=m210
#
# 아이언 자이언트
# ['애니메이션', 'SF', '액션', '가족']
# 9.32
# 1930
# https://movie-phinf.pstatic.net//20190826_143/1566796598455I2Amf_JPEG/movie_image.jpg?type=m210
#
# 프리퀀시
# ['범죄', '드라마', 'SF', '스릴러']
# 9.32
# 6123
# https://movie-phinf.pstatic.net//20111222_144/1324507551715hYCMY_JPEG/movie_image.jpg?type=m210
#
# 아이 엠 샘
# ['드라마']
# 9.32
# 3063
# https://movie-phinf.pstatic.net//20111222_30/1324551355578IOWKU_JPEG/movie_image.jpg?type=m210
#
# 해리 포터와 죽음의 성물 - 2부
# ['모험', '판타지', '미스터리']
# 9.31
# 11986
# https://movie-phinf.pstatic.net//20111223_74/1324640419980SJD8k_JPEG/movie_image.jpg?type=m210
#
# 소원
# ['드라마']
# 9.32
# 8446
# https://movie-phinf.pstatic.net//20130902_68/1378096688321WUTwq_JPEG/movie_image.jpg?type=m210
#
# 지상의 별처럼
# ['드라마']
# 9.32
# 900
# https://movie-phinf.pstatic.net//20120719_80/13426857031456QQI0_JPEG/movie_image.jpg?type=m210
#
# 주먹왕 랄프
# ['애니메이션', '코미디', '가족']
# 9.33
# 3091
# https://movie-phinf.pstatic.net//20121123_34/1353646026595Ju6dI_JPEG/movie_image.jpg?type=m210
#
# 번 더 스테이지: 더 무비
# []
# 9.31
# 2322
# https://movie-phinf.pstatic.net//20181109_286/1541743345207CtoXg_JPEG/movie_image.jpg?type=m210
#
# 코러스
# ['드라마']
# 9.31
# 3402
# https://movie-phinf.pstatic.net//20171208_286/1512694590425x9EjV_JPEG/movie_image.jpg?type=m210
#
# 모던 타임즈
# ['코미디']
# 9.31
# 1192
# https://movie-phinf.pstatic.net//20150210_110/1423530446210OeFV1_JPEG/movie_image.jpg?type=m210
#
# 업
# ['애니메이션', '가족', '모험', '코미디', '액션']
# 9.31
# 6155
# https://movie-phinf.pstatic.net//20111223_221/1324590426566npnJd_JPEG/movie_image.jpg?type=m210
#
# 빌리 엘리어트
# ['드라마', '가족', '코미디']
# 9.31
# 3457
# https://movie-phinf.pstatic.net//20170105_296/1483590193115rpMx5_JPEG/movie_image.jpg?type=m210
#
# 언더독
# ['애니메이션']
# 9.31
# 1453
# https://movie-phinf.pstatic.net//20181224_250/1545613244716iYHTg_JPEG/movie_image.jpg?type=m210
#
# 피아니스트
# ['드라마', '전쟁']
# 9.31
# 6436
# https://movie-phinf.pstatic.net//20150608_292/1433754164299kVDXs_JPEG/movie_image.jpg?type=m210
#
# 나 홀로 집에 2 - 뉴욕을 헤매다
# ['모험', '액션', '범죄', '스릴러', '코미디', '가족']
# 9.31
# 1581
# https://movie-phinf.pstatic.net//20111221_101/13244782467487AIcS_JPEG/movie_image.jpg?type=m210
#
# 러브 유어셀프 인 서울
# ['공연실황']
# 9.28
# 1410
# https://movie-phinf.pstatic.net//20181214_60/15447506226141Uiod_JPEG/movie_image.jpg?type=m210
#
# 바이센테니얼 맨
# ['SF', '드라마']
# 9.3
# 1943
# https://movie-phinf.pstatic.net//20111221_282/1324470047868yqNUI_JPEG/movie_image.jpg?type=m210
#
# 블라인드 사이드
# ['드라마']
# 9.31
# 4910
# https://movie-phinf.pstatic.net//20111223_159/13246089113705W9ps_JPEG/movie_image.jpg?type=m210
#
# 미스 슬로운
# ['드라마', '스릴러']
# 9.31
# 1420
# https://movie-phinf.pstatic.net//20170412_230/1491961688364Vftv5_JPEG/movie_image.jpg?type=m210
#
# 오세암
# ['애니메이션', '드라마']
# 9.3
# 2110
# https://movie-phinf.pstatic.net//20111222_125/1324507783843b9gEF_JPEG/movie_image.jpg?type=m210
#
# 아기공룡 둘리 - 얼음별 대모험
# ['애니메이션', '가족', '코미디', '모험', '뮤지컬']
# 9.3
# 464
# https://movie-phinf.pstatic.net//20111221_146/1324474085699H3JT7_JPEG/movie_image.jpg?type=m210
#
# 우리들의 일그러진 영웅
# ['드라마']
# 9.3
# 968
# https://movie-phinf.pstatic.net//20111221_284/1324452236681SMIDe_JPEG/movie_image.jpg?type=m210
#
# 쥬라기 공원
# ['SF', '액션', '모험']
# 9.28
# 1983
# https://movie-phinf.pstatic.net//20130531_210/13699689765823Nlai_JPEG/movie_image.jpg?type=m210
#
# 라따뚜이
# ['코미디', '가족', '모험', '애니메이션']
# 9.28
# 7348
# https://movie-phinf.pstatic.net//20111222_98/1324525988764xxfgr_JPEG/movie_image.jpg?type=m210
#
# 천공의 성 라퓨타
# ['애니메이션', '판타지', '모험']
# 9.3
# 2591
# https://movie-phinf.pstatic.net//20111222_264/1324541030764uwdKQ_JPEG/movie_image.jpg?type=m210
#
# 로망
# ['멜로/애정/로맨스']
# 9.3
# 568
# https://movie-phinf.pstatic.net//20190306_13/1551862037635qnE0r_JPEG/movie_image.jpg?type=m210
#
# 일급 살인
# ['드라마', '범죄']
# 9.3
# 1974
# https://movie-phinf.pstatic.net//20111222_237/1324564654860kKxJt_JPEG/movie_image.jpg?type=m210
#
# 내 이름은 칸
# ['드라마']
# 9.28
# 6021
# https://movie-phinf.pstatic.net//20111223_154/1324634519508BXcx5_JPEG/movie_image.jpg?type=m210
#
# 자백
# ['다큐멘터리']
# 9.28
# 3147
# https://movie-phinf.pstatic.net//20161004_45/1475545337972XDyUi_JPEG/movie_image.jpg?type=m210
#
# 시네마 천국
# ['드라마', '멜로/애정/로맨스']
# 9.28
# 3719
# https://movie-phinf.pstatic.net//20130911_232/1378878991812QfLTe_JPEG/movie_image.jpg?type=m210
#
# 토이 스토리
# ['애니메이션', '코미디', '가족', '판타지']
# 9.28
# 1351
# https://movie-phinf.pstatic.net//20111222_26/1324486740607KI01H_JPEG/movie_image.jpg?type=m210
#
# 퀸 락 몬트리올
# ['다큐멘터리']
# 9.28
# 329
# https://movie-phinf.pstatic.net//20111224_221/1324655339062piKsV_JPEG/movie_image.jpg?type=m210
#
# 에이 아이
# ['SF', '드라마', '판타지']
# 9.28
# 4290
# https://movie-phinf.pstatic.net//20111223_264/13245805774065e9Mn_JPEG/movie_image.jpg?type=m210
#
# 록키
# ['드라마', '액션']
# 9.28
# 1217
# https://movie-phinf.pstatic.net//20171115_176/1510728216956HOOe1_JPEG/movie_image.jpg?type=m210
#
# 천국의 아이들
# ['드라마', '코미디']
# 9.28
# 1148
# https://movie-phinf.pstatic.net//20170117_167/1484617736745cCu57_JPEG/movie_image.jpg?type=m210
#
# 레드슈즈
# ['애니메이션', '모험', '코미디', '판타지', '멜로/애정/로맨스']
# 9.28
# 3499
# https://movie-phinf.pstatic.net//20190725_193/1564022721149J72b7_JPEG/movie_image.jpg?type=m210
#
# 진행상황 2 /40 https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=pnt&date=20190825&page=3
# 영웅: 샐러멘더의 비밀
# ['액션']
# 9.28
# 15516
# https://movie-phinf.pstatic.net//20130123_23/1358932669644LPxFO_JPEG/movie_image.jpg?type=m210
#
# 뽀로로 극장판 보물섬 대모험
# ['애니메이션']
# 9.28
# 2443
# https://movie-phinf.pstatic.net//20190329_266/15538347866861YXl3_JPEG/movie_image.jpg?type=m210
#
# 다이 하드
# ['액션', '스릴러', '범죄']
# 9.28
# 871
# https://movie-phinf.pstatic.net//20111223_215/1324578397636Vn9Lq_JPEG/movie_image.jpg?type=m210
#
# 라이온 킹
# ['애니메이션', '모험', '드라마', '가족']
# 9.28
# 2205
# https://movie-phinf.pstatic.net//20190722_115/1563760451352h64Fo_JPEG/movie_image.jpg?type=m210
#
# 뷰티풀 투모로우
# ['드라마']
# 9.26
# 841
# https://movie-phinf.pstatic.net//20171030_54/1509334385029hwGdz_JPEG/movie_image.jpg?type=m210
#
# 천녀유혼
# ['판타지', '공포', '멜로/애정/로맨스', '액션']
# 9.28
# 1857
# https://movie-phinf.pstatic.net//20190325_20/155347869332414163_JPEG/movie_image.jpg?type=m210
#
# 세상에서 가장 아름다운 이별
# ['드라마', '가족']
# 9.28
# 3912
# https://movie-phinf.pstatic.net//20111223_2/13246354120826wuuA_JPEG/movie_image.jpg?type=m210
#
# 바람계곡의 나우시카
# ['애니메이션', 'SF']
# 9.28
# 1545
# https://movie-phinf.pstatic.net//20111222_106/1324528452873OMdC0_JPEG/movie_image.jpg?type=m210
#
# 반지의 제왕: 반지 원정대
# ['판타지', '모험', '액션']
# 9.28
# 3700
# https://movie-phinf.pstatic.net//20170112_293/1484183486221oM8s1_JPEG/movie_image.jpg?type=m210
#
# 타잔
# ['애니메이션', '가족', '모험']
# 9.28
# 460
# https://movie-phinf.pstatic.net//20111222_38/1324542328491At0b3_JPEG/movie_image.jpg?type=m210
#
# 빌리 엘리어트 뮤지컬 라이브
# ['공연실황']
# 9.26
# 376
# https://movie-phinf.pstatic.net//20141028_45/1414463799545BKScI_JPEG/movie_image.jpg?type=m210
#
# 몬스터 주식회사 3D
# ['애니메이션', '가족', '모험', '판타지', '코미디']
# 9.28
# 1738
# https://movie-phinf.pstatic.net//20130122_180/1358819064231daPKK_JPEG/movie_image.jpg?type=m210
#
# 엽기적인 그녀
# ['코미디', '드라마', '멜로/애정/로맨스']
# 9.28
# 4033
# https://movie-phinf.pstatic.net//20111223_278/1324577048430YYLpv_JPEG/movie_image.jpg?type=m210
#
# 폴리스 스토리
# ['액션', '코미디']
# 9.26
# 455
# https://movie-phinf.pstatic.net//20150312_242/1426141162841F2pco_JPEG/movie_image.jpg?type=m210
#
# 프리 윌리
# ['가족', '모험', '드라마']
# 9.26
# 347
# https://movie-phinf.pstatic.net//20111221_252/1324474358863cX2Ok_JPEG/movie_image.jpg?type=m210
#
# 허스토리
# ['드라마']
# 9.26
# 2387
# https://movie-phinf.pstatic.net//20180618_223/1529289387860nUBT1_JPEG/movie_image.jpg?type=m210
#
# 맨발의 꿈
# ['드라마']
# 9.26
# 3504
# https://movie-phinf.pstatic.net//20111223_86/1324613577990hG440_JPEG/movie_image.jpg?type=m210
#
# 동방불패
# ['액션', '드라마']
# 9.28
# 1234
# https://movie-phinf.pstatic.net//20131210_287/1386661099766jo0ls_JPEG/movie_image.jpg?type=m210
#
# 말할 수 없는 비밀
# ['멜로/애정/로맨스', '판타지', '드라마']
# 9.26
# 38030
# https://movie-phinf.pstatic.net//20150401_175/14278553671933quzs_JPEG/movie_image.jpg?type=m210
#
# 바람
# ['드라마', '액션', '가족']
# 9.26
# 9187
# https://movie-phinf.pstatic.net//20111223_242/1324597990008Nj67F_JPEG/movie_image.jpg?type=m210
#
# 메리 포핀스
# ['가족', '코미디', '뮤지컬', '판타지']
# 9.24
# 317
# https://movie-phinf.pstatic.net//20111222_46/1324482040732kfaGN_JPEG/movie_image.jpg?type=m210
#
# 교회오빠
# ['다큐멘터리']
# 9.26
# 1525
# https://movie-phinf.pstatic.net//20190327_111/15536621391952t7K8_JPEG/movie_image.jpg?type=m210
#
# 더 코브: 슬픈 돌고래의 진실
# ['다큐멘터리']
# 9.26
# 1596
# https://movie-phinf.pstatic.net//20111223_149/1324594571372cfQMs_JPEG/movie_image.jpg?type=m210
# 공동경비구역 JSA
# ['드라마', '전쟁', '코미디', '미스터리']
# 9.26
# 2492
# https://movie-phinf.pstatic.net//20111223_32/1324577751718PR2XX_JPEG/movie_image.jpg?type=m210
#
# 브레이브하트
# ['액션', '드라마', '전쟁']
# 9.26
# 2276
# https://movie-phinf.pstatic.net//20111223_36/1324634876338S6xxQ_JPEG/movie_image.jpg?type=m210
#
# 도가니
# ['드라마']
# 9.26
# 10216
# https://movie-phinf.pstatic.net//20111223_256/1324646334244okQ2O_JPEG/movie_image.jpg?type=m210
#
# 마이클 잭슨의 디스 이즈 잇
# ['다큐멘터리']
# 9.26
# 2100
# https://movie-phinf.pstatic.net//20111223_149/1324592649161HV1ry_JPEG/movie_image.jpg?type=m210
#
# 에이트 빌로우
# ['모험', '드라마', '가족']
# 9.25
# 4133
# https://movie-phinf.pstatic.net//20111221_294/1324453111090xBIEs_JPEG/movie_image.jpg?type=m210
#
# 온리 더 브레이브
# ['드라마']
# 9.26
# 1017
# https://movie-phinf.pstatic.net//20180219_45/1519027643063p4Gju_JPEG/movie_image.jpg?type=m210
#
# 코코
# ['애니메이션', '모험', '코미디']
# 9.26
# 15366
# https://movie-phinf.pstatic.net//20171222_56/1513906341368blx3Q_JPEG/movie_image.jpg?type=m210
#
# 오페라의 유령 : 25주년 특별 공연
# ['공연실황']
# 9.26
# 474
# https://movie-phinf.pstatic.net//20111224_80/1324654980579w1EP6_JPEG/movie_image.jpg?type=m210
#
# 인생
# ['드라마']
# 9.28
# 408
# https://movie-phinf.pstatic.net//20111221_92/13244550096878VBm9_JPEG/movie_image.jpg?type=m210
#
# 이웃집 토토로
# ['애니메이션', '가족', '판타지']
# 9.26
# 2934
# https://movie-phinf.pstatic.net//20190507_131/1557194421303SpmS0_JPEG/movie_image.jpg?type=m210
#
# 로미오와 줄리엣
# ['드라마', '멜로/애정/로맨스']
# 9.28
# 501
# https://movie-phinf.pstatic.net//20111223_211/1324586655256bklaD_JPEG/movie_image.jpg?type=m210
#
# 또 하나의 약속
# ['드라마']
# 9.26
# 5903
# https://movie-phinf.pstatic.net//20140106_7/1388972549520fQhce_JPEG/movie_image.jpg?type=m210
#
# 터미네이터
# ['SF', '액션', '스릴러']
# 9.26
# 1434
# https://movie-phinf.pstatic.net//20111222_137/1324507399293UsKfI_JPEG/movie_image.jpg?type=m210
#
# 트루맛쇼
# ['다큐멘터리']
# 9.25
# 2126
# https://movie-phinf.pstatic.net//20111223_40/1324638783572CfeUU_JPEG/movie_image.jpg?type=m210
#
# 쥬만지
# ['모험', '판타지', '가족', '액션', '코미디']
# 9.26
# 1476
# https://movie-phinf.pstatic.net//20111223_209/1324569135466HoEsQ_JPEG/movie_image.jpg?type=m210
#
# 나, 다니엘 블레이크
# ['드라마']
# 9.26
# 2003
# https://movie-phinf.pstatic.net//20161117_246/1479344102925C9Ens_JPEG/movie_image.jpg?type=m210
#
# 토이 스토리 2
# ['애니메이션', '모험']
# 9.26
# 923
# https://movie-phinf.pstatic.net//20111222_164/1324480061997pYUFr_JPEG/movie_image.jpg?type=m210
#
# 본 얼티메이텀
# ['액션', '미스터리', '스릴러']
# 9.25
# 8676
# https://movie-phinf.pstatic.net//20160628_2/1467080136011unJpU_JPEG/movie_image.jpg?type=m210
#
# 신데렐라 맨
# ['드라마', '멜로/애정/로맨스']
# 9.25
# 3471
# https://movie-phinf.pstatic.net//20111223_83/1324618952362vuCxq_JPEG/movie_image.jpg?type=m210
#
# 명탐정 코난: 베이커가의 망령
# ['애니메이션']
# 9.25
# 1548
# https://movie-phinf.pstatic.net//20111222_64/1324527093603Kc0Uk_JPEG/movie_image.jpg?type=m210
#
# 하이 스쿨 뮤지컬: 졸업반
# ['뮤지컬', '코미디', '드라마', '가족', '멜로/애정/로맨스']
# 9.25
# 2183
# https://movie-phinf.pstatic.net//20111223_250/1324572904017YpxxU_JPEG/movie_image.jpg?type=m210
#
# 우리들
# ['드라마']
# 9.26
# 1782
# https://movie-phinf.pstatic.net//20160519_125/1463633078640zLLTy_JPEG/movie_image.jpg?type=m210
#
# 늑대와 춤을
# ['서부', '드라마', '모험']
# 9.26
# 737
# https://movie-phinf.pstatic.net//20111222_284/1324531837148xPI9q_JPEG/movie_image.jpg?type=m210
#
# 취권 2
# ['액션', '코미디']
# 9.23
# 461
# https://movie-phinf.pstatic.net//20111222_287/1324538393763PHLew_JPEG/movie_image.jpg?type=m210
#
# 드래곤 길들이기 3
# ['애니메이션', '모험']
# 9.25
# 3957
# https://movie-phinf.pstatic.net//20190131_168/1548898773611USlT7_JPEG/movie_image.jpg?type=m210
#
# 패밀리 맨
# ['코미디', '드라마', '멜로/애정/로맨스', '판타지']
# 9.24
# 1937
# https://movie-phinf.pstatic.net//20111222_128/1324551257240i2tXP_JPEG/movie_image.jpg?type=m210
#
# 트와이스랜드
# ['다큐멘터리']
# 9.24
# 352
# https://movie-phinf.pstatic.net//20181126_28/1543198228641MuW4K_JPEG/movie_image.jpg?type=m210
#
# 진행상황 3 /40 https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=pnt&date=20190825&page=4
# 사랑은 비를 타고
# ['뮤지컬', '멜로/애정/로맨스', '코미디']
# 9.25
# 392
# https://movie-phinf.pstatic.net//20111223_95/1324577323974nbaUv_JPEG/movie_image.jpg?type=m210
#
# 가위손
# ['판타지', '멜로/애정/로맨스']
# 9.24
# 3764
# https://movie-phinf.pstatic.net//20140516_73/1400226339590GKGTd_JPEG/movie_image.jpg?type=m210
#
# 마이너리티 리포트
# ['SF', '드라마', '미스터리', '범죄', '액션']
# 9.24
# 2514
# https://movie-phinf.pstatic.net//20111222_144/1324533525558LSVPi_JPEG/movie_image.jpg?type=m210
#
# 보디가드
# ['액션']
# 9.25
# 378
# https://movie-phinf.pstatic.net//20111222_28/13245398841535psgo_JPEG/movie_image.jpg?type=m210
#
# 친정엄마
# ['드라마']
# 9.24
# 2550
# https://movie-phinf.pstatic.net//20111223_55/1324607938361EdETl_JPEG/movie_image.jpg?type=m210
#
# 위대한 독재자
# ['코미디']
# 9.26
# 383
# https://movie-phinf.pstatic.net//20150330_89/1427701328897Bu28M_JPEG/movie_image.jpg?type=m210
#
# 인크레더블
# ['애니메이션', '가족', '모험', '액션', '코미디']
# 9.24
# 3579
# https://movie-phinf.pstatic.net//20111221_118/1324470152897UVkHB_JPEG/movie_image.jpg?type=m210
#
# 미녀와 야수
# ['애니메이션', '가족', '드라마', '판타지', '멜로/애정/로맨스', '뮤지컬']
# 9.24
# 643
# https://movie-phinf.pstatic.net//20170418_8/1492495678811alblS_JPEG/movie_image.jpg?type=m210
#
# 해바라기
# ['액션', '드라마']
# 9.22
# 15772
# https://movie-phinf.pstatic.net//20111222_49/1324559296530Ns2Xc_JPEG/movie_image.jpg?type=m210
#
# 프린스 앤 프린세스
# ['애니메이션', '코미디', '가족']
# 9.24
# 322
# https://movie-phinf.pstatic.net//20111221_172/1324479317370KDLWx_JPEG/movie_image.jpg?type=m210
#
# 가타카
# ['SF', '드라마', '스릴러']
# 9.24
# 3746
# https://movie-phinf.pstatic.net//20111222_69/1324541836762R8tql_JPEG/movie_image.jpg?type=m210
#
# 집으로 가는 길
# ['드라마', '멜로/애정/로맨스']
# 9.24
# 374
# https://movie-phinf.pstatic.net//20111221_73/1324465452839k4iaY_JPEG/movie_image.jpg?type=m210
#
# 로보캅
# ['SF', '액션', '범죄']
# 9.24
# 598
# https://movie-phinf.pstatic.net//20111222_219/13244984250214YhOo_JPEG/movie_image.jpg?type=m210
#
# 광해, 왕이 된 남자
# ['드라마']
# 9.24
# 28026
# https://movie-phinf.pstatic.net//20121018_114/13505269047497LGt6_JPEG/movie_image.jpg?type=m210
#
# 쿨 러닝
# ['드라마', '코미디']
# 9.23
# 1429
# https://movie-phinf.pstatic.net//20111222_39/1324540209868FJEQw_JPEG/movie_image.jpg?type=m210
#
# 엽문
# ['액션', '드라마']
# 9.23
# 5293
# https://movie-phinf.pstatic.net//20180426_254/1524722492325paL1r_JPEG/movie_image.jpg?type=m210
#
# 극장판 헬로카봇 : 백악기 시대
# ['애니메이션']
# 9.23
# 2194
# https://movie-phinf.pstatic.net//20180712_119/1531377839011rdxSS_JPEG/movie_image.jpg?type=m210
#
# 석양에 돌아오다
# ['서부', '액션', '드라마', '모험']
# 9.23
# 383
# https://movie-phinf.pstatic.net//20130110_146/1357786939221cJBAy_JPEG/movie_image.jpg?type=m210
#
# 피아니스트의 전설
# ['드라마', '판타지', '뮤지컬']
# 9.23
# 2680
# https://movie-phinf.pstatic.net//20111222_253/1324487550535FPC7h_JPEG/movie_image.jpg?type=m210
#
# 뷰티풀 마인드
# ['드라마']
# 9.24
# 3498
# https://movie-phinf.pstatic.net//20111221_114/1324470706744EdNKe_JPEG/movie_image.jpg?type=m210
#
# 갓파 쿠와 여름방학을
# ['애니메이션']
# 9.23
# 2695
# https://movie-phinf.pstatic.net//20160725_78/1469413892794fLdOz_JPEG/movie_image.jpg?type=m210
#
# 고 녀석 맛나겠다
# ['애니메이션', '가족', '모험']
# 9.23
# 1136
# https://movie-phinf.pstatic.net//20111223_33/1324639304668v3hRK_JPEG/movie_image.jpg?type=m210
#
# 8월의 크리스마스
# ['드라마', '멜로/애정/로맨스']
# 9.23
# 2501
# https://movie-phinf.pstatic.net//20131024_116/13826089621478XXIl_JPEG/movie_image.jpg?type=m210
#
# 리멤버 타이탄
# ['가족', '드라마']
# 9.23
# 1776
# https://movie-phinf.pstatic.net//20111222_277/1324551255205hKU3b_JPEG/movie_image.jpg?type=m210
#
# 킹콩을 들다
# ['드라마']
# 9.23
# 8573
# https://movie-phinf.pstatic.net//20111223_299/1324587041674vE43S_JPEG/movie_image.jpg?type=m210
#
# 아저씨
# ['액션', '범죄', '드라마']
# 9.23
# 28455
# https://movie-phinf.pstatic.net//20111223_67/1324619531349Xc7vj_JPEG/movie_image.jpg?type=m210
#
# 인크레더블 2
# ['애니메이션', '액션', '모험']
# 9.23
# 10376
# https://movie-phinf.pstatic.net//20180711_9/1531285562987n5VUG_JPEG/movie_image.jpg?type=m210
#
# 빽 투 더 퓨쳐 2
# ['SF', '코미디']
# 9.24
# 1018
# https://movie-phinf.pstatic.net//20150924_127/14430563852692a3lU_JPEG/movie_image.jpg?type=m210
#
# 투게더
# ['드라마']
# 9.22
# 309
# https://movie-phinf.pstatic.net//20111222_39/1324556331971lrAkB_JPEG/movie_image.jpg?type=m210
#
# 1987
# ['드라마']
# 9.23
# 32670
# https://movie-phinf.pstatic.net//20171215_265/1513327177055W7qpm_JPEG/movie_image.jpg?type=m210
#
# 로마의 휴일
# ['코미디', '드라마', '멜로/애정/로맨스']
# 9.23
# 879
# https://movie-phinf.pstatic.net//20111221_184/1324464709015ggkNw_JPEG/movie_image.jpg?type=m210
#
# 님아, 그 강을 건너지 마오
# ['다큐멘터리']
# 9.23
# 15354
# https://movie-phinf.pstatic.net//20141103_255/1414988497460e1QB6_JPEG/movie_image.jpg?type=m210
#
# 니모를 찾아서 3D
# ['애니메이션', '모험', '코미디', '가족']
# 9.23
# 1604
# https://movie-phinf.pstatic.net//20130424_214/13667923570140Q9HA_JPEG/movie_image.jpg?type=m210
#
# 땐뽀걸즈
# ['다큐멘터리']
# 9.24
# 519
# https://movie-phinf.pstatic.net//20170830_7/1504069030981tJm5V_JPEG/movie_image.jpg?type=m210
#
# 똥파리
# ['드라마']
# 9.23
# 7037
# https://movie-phinf.pstatic.net//20111223_38/1324584197213BqKNm_JPEG/movie_image.jpg?type=m210
# 명탐정 코난: 천공의 난파선
# ['애니메이션', '모험', '가족']
# 9.23
# 3508
# https://movie-phinf.pstatic.net//20111223_107/13246162456260T0Ib_JPEG/movie_image.jpg?type=m210
#
# 타인의 삶
# ['드라마']
# 9.23
# 3240
# https://movie-phinf.pstatic.net//20130115_55/13582135898186wXUP_JPEG/movie_image.jpg?type=m210
#
# 해리 포터와 마법사의 돌
# ['판타지', '가족', '모험', '액션']
# 9.22
# 3294
# https://movie-phinf.pstatic.net//20181019_236/1539926790655oHv5z_JPEG/movie_image.jpg?type=m210
#
# 페이스 오프
# ['액션']
# 9.23
# 1816
# https://movie-phinf.pstatic.net//20111221_276/1324478294709bFeIq_JPEG/movie_image.jpg?type=m210
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f7fa2183f94c> in <module>
#      30         url2 = linkList[i]
#      31         page2 = urlopen(url2)
# ---> 32         soup2 = BeautifulSoup(page2, "html.parser")
#      33
#      34         #영화 이름과 장르 추출
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     242
#     243         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 244             markup = markup.read()
#     245         elif len(markup) <= 256 and (
#     246                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     452
#     453             if self.chunked:
# --> 454                 return self._readall_chunked()
#     455
#     456             if self.length is None:
#
# ~\Anaconda3\lib\http\client.py in _readall_chunked(self)
#     562                 if chunk_left is None:
#     563                     break
# --> 564                 value.append(self._safe_read(chunk_left))
#     565                 self.chunk_left = 0
#     566             return b''.join(value)
#
# ~\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     608         s = []
#     609         while amt > 0:
# --> 610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
#     612                 raise IncompleteRead(b''.join(s), amt)
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 영화 페이지 속에서 데이터 추출

# %%
import re
import csv
from bs4 import BeautifulSoup
from urllib.request import urlopen
mvGenre = []
comp = "/movie/sdb/browsing/bmovie.nhn?genre" # 비교용
for i in range(50):
    f = open('output.csv', 'a', encoding='utf-8', newline='')
    url2 = linkList[i]
    page = urlopen(url2)
    soup2 = BeautifulSoup(page, "html.parser")

    #영화 이름과 장르 추출
    mvTitle = soup2.find("div", {"class": "choice_movie_info"}).find("a").text
    
    for atag in soup2.find("div", {"class": "choice_movie_info"}).find("td").findAll("a"):
        if comp in str(atag):
            mvGenre.append(atag.text)
        
    print(mvTitle) #제목 크롤링
    print(mvGenre) #장르 크롤링

    #영화 평점 추출
    stPoint = soup2.find("div", {"class":"fl point_type_b"}).find("div")
    stPoint = str(stPoint)
    stPoint = stPoint[31:35]
    stPoint = float(stPoint)/10
    stPoint = round(stPoint, 2)
    print(stPoint)

    #영화 투표수 추출
    soup2.findAll("span")
    for i in soup2.findAll("td"):
        if i.find("em") != None:
            voteCnt = i.find("em").text
            print(voteCnt)

    # 영화 포스터 추출
    poster = soup2.find("div", {"class": "fl"}).find("img")['src']
    print(poster)
    print("")

    #csv 파일에 저장
    wr = csv.writer(f)
    wr.writerow([mvTitle, mvGenre, stPoint, voteCnt, poster])
    del mvGenre[:]
    f.close()
# Out:
# 의뢰인
# ['드라마', '스릴러']
# 8.05
# 4894
# https://movie-phinf.pstatic.net//20111223_142/1324646482436YSvXF_JPEG/movie_image.jpg?type=m210
#
# 007 카지노 로얄
# ['액션', '모험']
# 8.05
# 2576
# https://movie-phinf.pstatic.net//20111223_28/1324574584370mQIAu_JPEG/movie_image.jpg?type=m210
#
# 은하수를 여행하는 히치하이커를 위..
# ['모험', '코미디', 'SF']
# 8.05
# 1300
# https://movie-phinf.pstatic.net//20111221_166/1324462604648yqHvD_JPEG/movie_image.jpg?type=m210
#
# 레드
# ['액션']
# 8.05
# 1945
# https://movie-phinf.pstatic.net//20111223_78/1324625094466o5wfM_JPEG/movie_image.jpg?type=m210
#
# 만신
# ['다큐멘터리', '드라마']
# 8.03
# 539
# https://movie-phinf.pstatic.net//20140220_236/13928808624143L8yu_JPEG/movie_image.jpg?type=m210
#
# 바보
# ['드라마']
# 8.05
# 3417
# https://movie-phinf.pstatic.net//20111223_182/1324573606992N7kup_JPEG/movie_image.jpg?type=m210
#
# 문라이트
# ['드라마']
# 8.03
# 2231
# https://movie-phinf.pstatic.net//20170302_58/1488416850453iGsh1_JPEG/movie_image.jpg?type=m210
#
# 하와이언 레시피
# ['드라마']
# 8.09
# 331
# https://movie-phinf.pstatic.net//20120702_196/1341220662967EK4uR_JPEG/movie_image.jpg?type=m210
#
# 삼거리 극장
# ['뮤지컬']
# 8.03
# 746
# https://movie-phinf.pstatic.net//20111222_292/1324562630805Eg1u1_JPEG/movie_image.jpg?type=m210
#
# 딥워터 호라이즌
# ['액션', '드라마']
# 8.06
# 894
# https://movie-phinf.pstatic.net//20170102_156/1483339338700qH0kh_JPEG/movie_image.jpg?type=m210
#
# 엑소시즘 오브 에밀리 로즈
# ['범죄', '드라마', '공포', '스릴러']
# 8.05
# 1130
# https://movie-phinf.pstatic.net//20111221_127/1324460321485z7oHx_JPEG/movie_image.jpg?type=m210
#
# 더 울프 오브 월 스트리트
# ['코미디', '범죄', '드라마']
# 8.07
# 4299
# https://movie-phinf.pstatic.net//20140123_84/1390455489585Risz0_JPEG/movie_image.jpg?type=m210
#
# 렛 미 인
# ['드라마', '판타지', '공포', '멜로/애정/로맨스', '스릴러']
# 8.05
# 1807
# https://movie-phinf.pstatic.net//20111223_108/1324625661785S9oEW_JPEG/movie_image.jpg?type=m210
#
# 타이페이 카페 스토리
# ['드라마', '멜로/애정/로맨스']
# 8.06
# 364
# https://movie-phinf.pstatic.net//20111223_260/1324639127015oLJfr_JPEG/movie_image.jpg?type=m210
#
# 바르게 살자
# ['코미디']
# 8.03
# 5092
# https://movie-phinf.pstatic.net//20111222_74/1324560950013hmyqS_JPEG/movie_image.jpg?type=m210
#
# 이층의 악당
# ['코미디', '범죄']
# 8.03
# 2635
# https://movie-phinf.pstatic.net//20111223_112/13246267229425B0NC_JPEG/movie_image.jpg?type=m210
#
# 박물관이 살아있다 : 비밀의 무덤
# ['모험', '코미디', '가족', '판타지']
# 8.06
# 2244
# https://movie-phinf.pstatic.net//20150109_19/14207956343469W4yX_JPEG/movie_image.jpg?type=m210
#
# 버티칼 리미트
# ['모험', '드라마', '액션', '스릴러']
# 8.03
# 364
# https://movie-phinf.pstatic.net//20111223_182/13245828119304T8NT_JPEG/movie_image.jpg?type=m210
#
# 어깨동무
# ['코미디']
# 8.03
# 950
# https://movie-phinf.pstatic.net//20111222_239/1324557431097pzJTW_JPEG/movie_image.jpg?type=m210
#
# 콜래트럴
# ['범죄', '드라마', '스릴러']
# 8.03
# 1881
# https://movie-phinf.pstatic.net//20111221_39/1324459127456gDN79_JPEG/movie_image.jpg?type=m210
#
# 어디선가 누군가에 무슨 일이 생기..
# ['코미디', '멜로/애정/로맨스']
# 8.01
# 829
# https://movie-phinf.pstatic.net//20111222_55/1324555258018l2RMz_JPEG/movie_image.jpg?type=m210
#
# 베스트 키드
# ['액션', '드라마', '가족']
# 8.03
# 1625
# https://movie-phinf.pstatic.net//20111223_134/1324616435786uNWas_JPEG/movie_image.jpg?type=m210
#
# 머시니스트
# ['스릴러', '드라마']
# 8.03
# 1171
# https://movie-phinf.pstatic.net//20160810_255/14708076991106tIh7_JPEG/movie_image.jpg?type=m210
#
# 라스트 사무라이
# ['액션', '모험', '드라마', '전쟁']
# 8.03
# 1829
# https://movie-phinf.pstatic.net//20111221_140/132445783688054a9o_JPEG/movie_image.jpg?type=m210
#
# 드레스메이커
# ['드라마']
# 8.11
# 498
# https://movie-phinf.pstatic.net//20151229_182/1451353480296F561I_JPEG/movie_image.jpg?type=m210
#
# 프리즈 프레임
# ['스릴러', '범죄', '드라마']
# 8.03
# 611
# https://movie-phinf.pstatic.net//20111221_239/1324459449118XdVl3_JPEG/movie_image.jpg?type=m210
#
# 나우 유 씨 미 : 마술사기단
# ['범죄', '스릴러', '미스터리']
# 8.03
# 9570
# https://movie-phinf.pstatic.net//20130708_96/13732598928852B7W7_JPEG/movie_image.jpg?type=m210
#
# 타워
# ['드라마']
# 8.03
# 14215
# https://movie-phinf.pstatic.net//20121206_104/1354758498530WnR2g_JPEG/movie_image.jpg?type=m210
#
# 레지던트 이블 2
# ['액션', '공포', 'SF', '스릴러']
# 8.03
# 1648
# https://movie-phinf.pstatic.net//20111223_13/1324577884814ITrnf_JPEG/movie_image.jpg?type=m210
#
# 고양이를 빌려드립니다
# ['드라마', '코미디']
# 8.01
# 379
# https://movie-phinf.pstatic.net//20121128_8/1354091092606Bwq6B_JPEG/movie_image.jpg?type=m210
#
# 해롤드와 쿠마
# ['코미디', '모험']
# 8.03
# 522
# https://movie-phinf.pstatic.net//20111221_214/13244634501310BLE1_JPEG/movie_image.jpg?type=m210
#
# 엑스맨
# ['SF', '액션']
# 8.03
# 883
# https://movie-phinf.pstatic.net//20111222_228/1324498782503dJ3IW_JPEG/movie_image.jpg?type=m210
#
# 오션스 일레븐
# ['범죄', '코미디']
# 8.01
# 947
# https://movie-phinf.pstatic.net//20111222_295/1324531366643q7BRh_JPEG/movie_image.jpg?type=m210
#
# 존 윅 - 리로드
# ['액션', '범죄', '스릴러']
# 8.03
# 2310
# https://movie-phinf.pstatic.net//20170221_170/1487660350597Fn5yI_JPEG/movie_image.jpg?type=m210
#
# 조작된 도시
# ['액션', '범죄']
# 8.03
# 16900
# https://movie-phinf.pstatic.net//20170206_87/1486347556947SbfPd_JPEG/movie_image.jpg?type=m210
#
# 쿠보와 전설의 악기
# ['애니메이션', '모험', '가족', '판타지']
# 8.03
# 325
# https://movie-phinf.pstatic.net//20160920_156/1474347348571tAzrJ_JPEG/movie_image.jpg?type=m210
#
# 슈렉 포에버
# ['애니메이션', '모험', '코미디', '가족', '판타지']
# 8.01
# 1461
# https://movie-phinf.pstatic.net//20111223_93/1324617532942Pyz5c_JPEG/movie_image.jpg?type=m210
#
# 신의 한 수
# ['범죄', '액션']
# 8.03
# 11865
# https://movie-phinf.pstatic.net//20140603_16/1401760272322q7OHX_JPEG/movie_image.jpg?type=m210
#
# 나쵸 리브레
# ['코미디']
# 8.56
# 68
# https://movie-phinf.pstatic.net//20111222_266/1324552466151T66a2_JPEG/movie_image.jpg?type=m210
#
# 13시간
# ['액션', '드라마', '스릴러']
# 8.05
# 1215
# https://movie-phinf.pstatic.net//20160225_151/14563917926629G1Ci_JPEG/movie_image.jpg?type=m210
#
# 인천상륙작전
# ['전쟁', '드라마']
# 8.01
# 40339
# https://movie-phinf.pstatic.net//20160715_16/1468568203431zYbBs_JPEG/movie_image.jpg?type=m210
#
# 미 마이셀프 앤드 아이린
# ['코미디']
# 8.01
# 485
# https://movie-phinf.pstatic.net//20111222_168/1324551193601mYJgr_JPEG/movie_image.jpg?type=m210
#
# 8명의 여인들
# ['코미디', '범죄', '뮤지컬', '미스터리']
# 8.01
# 389
# https://movie-phinf.pstatic.net//20111222_38/13245291108920KrcC_JPEG/movie_image.jpg?type=m210
#
# 아스트로 보이 - 아톰의 귀환
# ['애니메이션', 'SF', '가족', '액션']
# 8.01
# 989
# https://movie-phinf.pstatic.net//20111223_141/13246020188364e5Qv_JPEG/movie_image.jpg?type=m210
#
# 미스 페티그루의 어느 특별한 하루
# ['코미디', '멜로/애정/로맨스']
# 8.01
# 433
# https://movie-phinf.pstatic.net//20111222_161/1324523986442IPqAa_JPEG/movie_image.jpg?type=m210
#
# 인썸니아
# ['스릴러']
# 8.01
# 670
# https://movie-phinf.pstatic.net//20111222_251/13245404052988HLb6_JPEG/movie_image.jpg?type=m210
#
# 태양의 눈물
# ['전쟁', '액션', '드라마', '스릴러']
# 8.01
# 941
# https://movie-phinf.pstatic.net//20111222_50/1324562500020ltt4k_JPEG/movie_image.jpg?type=m210
#
# 위핏
# ['드라마']
# 8.01
# 377
# https://movie-phinf.pstatic.net//20111223_280/1324603191493bKAXU_JPEG/movie_image.jpg?type=m210
#
# 두번째 사랑
# ['멜로/애정/로맨스', '드라마']
# 8.01
# 893
# https://movie-phinf.pstatic.net//20111223_202/1324583459627VgTbB_JPEG/movie_image.jpg?type=m210
#
# 분노의 질주: 홉스&쇼
# ['액션']
# 8.0
# 7126
# https://movie-phinf.pstatic.net//20190726_177/15641046254730gK1F_JPEG/movie_image.jpg?type=m210

# %% [markdown]
# ### 영화 이름과 장르 추출

# %%
import re
from bs4 import BeautifulSoup
from urllib.request import urlopen
url = "https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=11002"
page = urlopen(url)
soup = BeautifulSoup(page, "html.parser")

# %%
#print(soup.find("div", {"class": "choice_movie_info"}).find("a").text) #제목 크롤링
tog = []
comp = "/movie/sdb/browsing/bmovie.nhn?genre" # 비교용
for atag in soup.find("div", {"class": "choice_movie_info"}).find("td").findAll("a"):
    if comp in str(atag):
        tog.append(atag.text)
        
        
print(tog)
# Out:
# ['SF', '액션', '드라마', '미스터리']

# %%
print(soup.find("div", {"class": "choice_movie_info"}).find("td").find("a").text) #장르 크롤링
# Out:
# SF

# %% [markdown]
# ### 영화 평점 추출

# %%
stPoint = soup.find("div", {"class":"fl point_type_b"}).find("div")
stPoint = str(stPoint)
stPoint = stPoint[31:35]
stPoint = float(stPoint)/10
print(stPoint)
# Out:
# 9.61

# %% [markdown]
# ### 영화 투표수 추출

# %%
soup.findAll("span")
for i in soup.findAll("td"):
    if i.find("em") != None:
        print(i.find("em").text)
# Out:
# 5937

# %% [markdown]
# ### 영화 포스터 링크 추출

# %%
f = soup.find("div", {"class": "fl"}).find("img")['src']
print(f)
# Out:
# https://movie-phinf.pstatic.net//20160810_49/14708058043034cuPp_JPEG/movie_image.jpg?type=m210

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("output.csv", sep=",", dtype='unicode')
df2 = data.drop_duplicateslicates()
